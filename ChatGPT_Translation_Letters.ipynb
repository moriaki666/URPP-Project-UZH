# %%
import pandas as pd
import openai
import tiktoken

# %%
#Do not Run
#Initialize the OpenAI API key
#openai.api_key = 'YOUR_API_KEY'

# %%
def count_tokens(text):
    encoding = tiktoken.get_encoding("p50k_base")
    return len(encoding.encode(text))

# %%
# Define the function to split text into chunks based on token count
def split_text_into_chunks(text, max_tokens):
    encoding = tiktoken.get_encoding("p50k_base")  # Use the appropriate encoding
    tokens = encoding.encode(text)  # Tokenize the entire text
    chunks = []

    # Split tokens into chunks
    for i in range(0, len(tokens), max_tokens):
        chunk_tokens = tokens[i:i + max_tokens]
        chunk_text = encoding.decode(chunk_tokens)
        chunks.append(chunk_text)

    return chunks

# %%
#Load dataset
dataset = pd.read_csv('/Users/manaswimondol/Desktop/Jupyter Notebooks/URPP/extracted_content.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   File                603 non-null    object
#  1   Title               603 non-null    object
#  2   Contributors        603 non-null    object
#  3   Description (DE)    603 non-null    object
#  4   Description (EN)    603 non-null    object
#  5   Document Details    603 non-null    object
#  6   Manuscript Details  603 non-null    object
#  7   Transcription       603 non-null    object
#  8   Critical Apparatus  532 non-null    object
# dtypes: object(9)
# memory usage: 42.5+ KB

# %%
dataset.head()
# Out:
#                                                 File  \
# 0  content.php-dir=edoc|ed000248&distype=optional...
# 1  content.php-dir=edoc|ed000248&distype=optional...
# 2  content.php-dir=edoc|ed000248&distype=optional...
# 3  content.php-dir=edoc|ed000248&distype=optional...
# 4  content.php-dir=edoc|ed000248&distype=optional...
#
#                                                Title  \
# 0  Glückwunsch zur Geburt einer Tochter (Lüneburg...
# 1  Fragment eines Kondolenzbriefes (Lüneburg, Klo...
# 2  Zitatesammlung und Fragment  zum Thema ‚Tribul...
# 3  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
# 4  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
#
#                                         Contributors  \
# 0  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 1  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 2  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 3  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# ...

# %%
dataset['token_count'] = dataset['Transcription'].apply(count_tokens)

# %%
dataset.head()
# Out:
#                                                 File  \
# 0  content.php-dir=edoc|ed000248&distype=optional...
# 1  content.php-dir=edoc|ed000248&distype=optional...
# 2  content.php-dir=edoc|ed000248&distype=optional...
# 3  content.php-dir=edoc|ed000248&distype=optional...
# 4  content.php-dir=edoc|ed000248&distype=optional...
#
#                                                Title  \
# 0  Glückwunsch zur Geburt einer Tochter (Lüneburg...
# 1  Fragment eines Kondolenzbriefes (Lüneburg, Klo...
# 2  Zitatesammlung und Fragment  zum Thema ‚Tribul...
# 3  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
# 4  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
#
#                                         Contributors  \
# 0  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 1  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 2  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 3  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# ...

# %%
max_tokens = 1600
dataset.describe()
# Out:
#        token_count
# count   603.000000
# mean   1143.184080
# std     837.628672
# min      28.000000
# 25%     538.500000
# 50%     977.000000
# 75%    1528.000000
# max    5121.000000

# %%
dataset['text_chunks'] = dataset['Transcription'].apply(lambda x: split_text_into_chunks(x, max_tokens))

# %%
# Function to count the number of chunks
def count_chunks(chunks):
    return len(chunks)

# %%
# Apply the count_chunks function to count the number of chunks
dataset['num_chunks'] = dataset['text_chunks'].apply(count_chunks)

# %%
dataset.head()
# Out:
#                                                 File  \
# 0  content.php-dir=edoc|ed000248&distype=optional...
# 1  content.php-dir=edoc|ed000248&distype=optional...
# 2  content.php-dir=edoc|ed000248&distype=optional...
# 3  content.php-dir=edoc|ed000248&distype=optional...
# 4  content.php-dir=edoc|ed000248&distype=optional...
#
#                                                Title  \
# 0  Glückwunsch zur Geburt einer Tochter (Lüneburg...
# 1  Fragment eines Kondolenzbriefes (Lüneburg, Klo...
# 2  Zitatesammlung und Fragment  zum Thema ‚Tribul...
# 3  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
# 4  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
#
#                                         Contributors  \
# 0  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 1  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 2  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 3  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# ...

# %%
random_row = dataset.sample(n=1)  # Randomly select one row
random_text = random_row['Transcription'].values[0]  # Replace 'text_column' with the actual column name

# Apply the split_text_into_chunks function to the selected text
chunk_example = split_text_into_chunks(random_text, max_tokens)

# Print the chunks
print(f"Original text (tokens: {count_tokens(random_text)}):\n{random_text}")
print("\nChunks:")
for idx, chunk in enumerate(chunk_example):
    print(f"Chunk {idx+1} (tokens: {count_tokens(chunk)}):")
    print(chunk)
    print("-" * 40)
# Out:
# Original text (tokens: 1365):
# 1 Jesum Christum
#                 vsen  alderleuesten  brudegham de de is de
# ...

# %%
#Do not Run
#output_path = 'extracted_translated_letters_preprocessed.csv'  # Specify the output file path
#dataset.to_csv(output_path, index=False)

# %%
total = dataset['token_count'].sum()
# Print the result
print(f"The total of the tokens in the dataset is: {total}")
# Out:
# The total of the tokens in the dataset is: 689340

# %%
from openai import OpenAI

# %%
## Set the API key
client = OpenAI(api_key="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")

# %%
MODEL="gpt-4o"

completion = client.chat.completions.create(
  model=MODEL,
  messages=[
    {"role": "system", "content": "You are a helpful assistant that helps me with my math homework!"},
    {"role": "user", "content": "Hello! Could you solve 20 x 5?"}
  ]
)
print("Assistant: " + completion.choices[0].message.content)
# Out:
# Assistant: Of course!
#
# 20 multiplied by 5 is:
#
# \[ 20 \times 5 = 100 \]
#
# So, the answer is 100.

# %%
# API KEY OPEN AI 
#

# %%
#Do not Run
#Initialize the OpenAI API key
#openai.api_key = 'YOUR_API_KEY'

# %%
def translate_text(chunk, target_language):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": f"Translate the following text to {target_language}:"},
            {"role": "user", "content": chunk}
        ]
    )
    translated_text = response.choices[0].message.content.strip()
    return translated_text

# %%
# Define the function to translate the entire text
def translate_large_text(text, max_tokens_per_chunk, target_language):
    chunks = split_text_into_chunks(text, max_tokens_per_chunk)
    translated_chunks = [translate_text(chunk, target_language) for chunk in chunks]
    translated_text = "\n".join(translated_chunks)
    return translated_text

# %%
max_tokens_per_chunk = 1600  # Adjust based on your needs and the token limit
target_language = 'English'  # Target language for translation

# Apply the translation function to a specific column in the DataFrame
dataset['translated_text'] = dataset['Transcription'].apply(
    lambda x: translate_large_text(x, max_tokens_per_chunk, target_language)
)

# Inspect the output
print(dataset[['Transcription', 'translated_text']].head())
# Out:
#                                        Transcription  \
# 0  1 Den a Vader der ewighen ere de alle dingh va...
# 1  1 Agnus paschalis qui sua innocenti morte oves...
# 2  1 Tribulatio a 2 Grego. Si passio Christi ad m...
# 3  1  [J]esum a Christum den schonen  bloyenden  ...
# 4  1  [J]esum a Christum sponsum nostrum qui est ...
#
#                                      translated_text
# 0  1. All honor to the eternal Father who created...
# 1  1. The Paschal Lamb, who by his innocent death...
# 2  1. Tribulation from 2 Gregory. If the passion ...
# 3  1. Jesus Christ, the beautiful blooming rose t...
# 4  1 [J]esus Christ, our bridegroom, who is the l...

# %%
dataset = dataset.rename(columns={'translated_text': 'GPT_translated_text'})

# %%
dataset.head()
# Out:
#                                                 File  \
# 0  content.php-dir=edoc|ed000248&distype=optional...
# 1  content.php-dir=edoc|ed000248&distype=optional...
# 2  content.php-dir=edoc|ed000248&distype=optional...
# 3  content.php-dir=edoc|ed000248&distype=optional...
# 4  content.php-dir=edoc|ed000248&distype=optional...
#
#                                                Title  \
# 0  Glückwunsch zur Geburt einer Tochter (Lüneburg...
# 1  Fragment eines Kondolenzbriefes (Lüneburg, Klo...
# 2  Zitatesammlung und Fragment  zum Thema ‚Tribul...
# 3  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
# 4  Dankesbrief (Lüneburg, Kloster Lüne, Hs. 15, L...
#
#                                         Contributors  \
# 0  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 1  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 2  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# 3  Herausgegeben von Eva Schlotheuber (Heinrich-H...
# ...

# %%
output_path = 'Translated_letters_ChatGPT.csv'  # Specify the output file path
dataset.to_csv(output_path, index=False)
